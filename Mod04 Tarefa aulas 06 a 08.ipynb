# %% [markdown]
# # Tarefa 03
#
# - Leia os enunciados com atenção
# - Saiba que pode haver mais de uma resposta correta
# - Insira novas células de código sempre que achar necessário
# - Em caso de dúvidas, procure os Tutores
# - Divirta-se :)

# %%
import pandas as pd
import requests

# %% [markdown]
# ####  1) Lendo de APIs
# Vimos em aula como carregar dados públicos do governo através de um API (*Application Programming Interface*). No exemplo de aula, baixamos os dados de pedidos de verificação de limites (PVL) realizados por estados, e selecionamos apenas aqueles referentes ao estado de São Paulo.
#
# 1. Repita os mesmos passos feitos em aula, mas selecione os PVLs realizados por municípios no estado do Rio de Janeiro.
# 2. Quais são os três *status* das solicitações mais frequentes na base? Quais são suas frequências?
# 3. Construa uma nova variável que contenha o ano do **status**. Observe que ```data_status``` vem como tipo *object* no **DataFrame**. Dica: você pode usar o método ```.str``` para transformar o tipo da variável em string, em seguida um método como [**slice()**](https://pandas.pydata.org/docs/reference/api/pandas.Series.str.slice.html) ou [**split()**](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.str.split.html).
# 4. Indique a frequência de cada ano do campo construído no item (3).

# %%
# 1) Seu código aqui

url = 'https://apidatalake.tesouro.gov.br/ords/sadipem/tt/pvl'

r = requests.get(url)

# %%
r.json()
# Out:
# {'items': [{'id_pleito': 17894,
#    'tipo_interessado': 'Município',
#    'interessado': 'Canela',
#    'cod_ibge': 4304408,
#    'uf': 'RS',
#    'num_pvl': None,
#    'status': 'Deferido',
#    'num_processo': '19406.000599/2006-41',
#    'data_protocolo': '2006-11-10T02:00:00Z',
#    'tipo_operacao': 'Operação contratual interna',
#    'finalidade': 'Provias',
#    'tipo_credor': 'Instituição Financeira Nacional',
#    'credor': 'BADESUL Desenvolvimento S.A. - Agência de Fomento/RS',
#    'moeda': 'Real',
#    'valor': 1250000,
#    'pvl_assoc_divida': 0,
#    'pvl_contradado_credor': 0,
#    'data_status': '24/11/2006'},
#   {'id_pleito': 16762,
#    'tipo_interessado': 'Município',
#    'interessado': 'Gaspar',
#    'cod_ibge': 4205902,
#    'uf': 'SC',
#    'num_pvl': None,
#    'status': 'Deferido',
#    'num_processo': '19406.000353/2008-31',
#    'data_protocolo': '2008-05-23T03:00:00Z',
#    'tipo_operacao': 'Operação contratual interna',
# ...

# %%
r.status_code
# Out:
# 200

# %%
data_json = r.json()

# %%
df = pd.DataFrame(data_json['items'])

# %%
df.head(2)
# Out:
#    id_pleito tipo_interessado interessado  cod_ibge  uf num_pvl    status  \
# 0      17894        Município      Canela   4304408  RS    None  Deferido
# 1      16762        Município      Gaspar   4205902  SC    None  Deferido
#
#            num_processo        data_protocolo                tipo_operacao  \
# 0  19406.000599/2006-41  2006-11-10T02:00:00Z  Operação contratual interna
# 1  19406.000353/2008-31  2008-05-23T03:00:00Z  Operação contratual interna
#
#             finalidade                      tipo_credor  \
# 0              Provias  Instituição Financeira Nacional
# 1  Caminho da Escola 2  Instituição Financeira Nacional
#
#                                               credor moeda      valor  \
# 0  BADESUL Desenvolvimento S.A. - Agência de Fome...  Real  1250000.0
# 1                            Caixa Econômica Federal  Real   472150.0
#
#    pvl_assoc_divida  pvl_contradado_credor data_status
# 0                 0                      0  24/11/2006
# ...

# %%
vetor_bool = df['uf'] == 'RJ' # condição booleana para indexar somente linhas cujo valor da coluna UF seja igual a RJ
vetor_bool
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4995    False
# 4996    False
# 4997    False
# 4998    False
# 4999    False
# Name: uf, Length: 5000, dtype: bool

# %%
df_rj = df[vetor_bool] # filtrando o dataframe apenas com valores verdadeiros para RJ
df_rj.head(3)
# Out:
#      id_pleito tipo_interessado     interessado  cod_ibge  uf num_pvl  \
# 132      10396        Município     São Gonçalo   3304904  RJ    None
# 178       9096        Município        Cordeiro   3301504  RJ    None
# 206       8050        Município  Rio de Janeiro   3304557  RJ    None
#
#         status          num_processo        data_protocolo  \
# 132  Arquivado  17944.001190/2008-91  2008-04-14T03:00:00Z
# 178  Arquivado  17944.000902/2008-54  2008-06-16T03:00:00Z
# 206   Deferido  17944.000703/2010-61  2011-04-29T03:00:00Z
#
#                    tipo_operacao                 finalidade  \
# 132  Operação contratual interna  PAC - Saneamento - 2008 B
# 178  Operação contratual interna        Caminho da Escola 2
# 206  Operação contratual interna                      PNAFM
#
#                          tipo_credor                   credor moeda  \
# 132  Instituição Financeira Nacional  Caixa Econômica Federal  Real
# ...

# %%
# 2) Seu código aqui

freq_status = df_rj['status'].value_counts()
print('Os 3 status mais frequentes na base de dados:\n', freq_status.head(3))
# Out:
# Os 3 status mais frequentes na base de dados:
#  Deferido                                                 25
# Encaminhado à PGFN com manifestação técnica favorável    13
# Arquivado                                                11
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

ano_status = df_rj['data_status'].str.split(pat='/', expand=True)[2]
ano_status
# Out:
# 132     2008
# 178     2008
# 206     2011
# 335     2009
# 476     2023
#         ...
# 4591    2008
# 4788    2008
# 4793    2023
# 4823    2008
# 4853    2020
# Name: 2, Length: 72, dtype: object

# %%
# 4) Seu código aqui

freq_ano = ano_status.value_counts()
freq_ano
# Out:
# 2008    11
# 2020     9
# 2007     7
# 2012     6
# 2010     5
# 2014     4
# 2013     4
# 2019     4
# 2009     3
# 2023     3
# 2011     3
# 2006     3
# 2002     3
# 2022     2
# 2016     2
# 2017     2
# 2021     1
# Name: 2, dtype: int64

# %% [markdown]
# ####  2) Melhorando a interação com o API
# Observe dois URLs de consultas diferentes, por exemplo o URL utilizado em aula, e o URL feito no exercício anterior. Compare-os e observe as diferenças.
#
# 1. Faça uma função em Python que recebe como argumento o UF da consulta e o tipo de interessado (```'Estado'```ou ```Município```), e que devolve os dados da consulta no formato *DataFrame*.
# 2. Quantas solicitações para o Estado podem ser consultadas para Minas Gerais com *status* em 'Arquivado por decurso de prazo' estão registradas?
# 3. Qual é o município da Bahia com mais solicitações deferidas?
# 4. Salve um arquivo .csv com os dados de solicitações da Bahia, com interessado = 'Estado'

# %%
#1) Seu código aqui

def consulta_dados(uf: str, tipo_interessado: str) -> pd.DataFrame():
    vetor_bool = df['uf'] == uf
    df_uf = df[vetor_bool]
    df_interessado = df_uf.loc[df_uf['tipo_interessado'] == tipo_interessado]
    return pd.DataFrame(df_interessado)

# %%
teste_func = consulta_dados(uf='RJ', tipo_interessado='Município')
teste_func.head(2)
# Out:
#      id_pleito tipo_interessado  interessado  cod_ibge  uf num_pvl     status  \
# 132      10396        Município  São Gonçalo   3304904  RJ    None  Arquivado
# 178       9096        Município     Cordeiro   3301504  RJ    None  Arquivado
#
#              num_processo        data_protocolo                tipo_operacao  \
# 132  17944.001190/2008-91  2008-04-14T03:00:00Z  Operação contratual interna
# 178  17944.000902/2008-54  2008-06-16T03:00:00Z  Operação contratual interna
#
#                     finalidade                      tipo_credor  \
# 132  PAC - Saneamento - 2008 B  Instituição Financeira Nacional
# 178        Caminho da Escola 2  Instituição Financeira Nacional
#
#                       credor moeda       valor  pvl_assoc_divida  \
# 132  Caixa Econômica Federal  Real  10000000.0                 0
# 178      Banco do Brasil S/A  Real    126750.0                 0
#
#      pvl_contradado_credor data_status
# 132                      0  15/09/2008
# ...

# %%
# 2) Seu código aqui

df_minas = consulta_dados(uf='MG', tipo_interessado='Estado')

arquivados_minas = df_minas['status'].value_counts()
arquivados_minas
# Out:
# Encaminhado à PGFN com manifestação técnica favorável    6
# Arquivado a pedido                                       2
# Deferido                                                 2
# Arquivado                                                2
# Name: status, dtype: int64

# %%
# 3) Seu código aqui

df_ba = consulta_dados(uf='BA', tipo_interessado='Município')

deferidos_ba = df_ba['status'].value_counts()
deferidos_ba.head(1)
# Out:
# Deferido    98
# Name: status, dtype: int64

# %%
# 4) Seu código aqui

df_bahia = consulta_dados(uf='BA', tipo_interessado='Estado')
df_bahia.to_csv('df_bahia.csv', index=False)
