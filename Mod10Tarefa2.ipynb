# %% [markdown]
# # Módulo 10 tarefa 2
#
# Considere a mesma base de dados utilizada na tarefa 1 ```previsao_de_renda.csv```.

# %% [markdown]
# 1) Com o que você viu em aula, faça uma análise das variáveis qualitativas (posse de imóvel e posse de veículo) para verificar se são boas preditoras de *renda*. Alguma delas parece discriminar *renda* de forma estatisticamente significante?

# %% [markdown]
# Biblioteca de importação

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
# Fixing random state for reproducibility
np.random.seed(2360873)
N = 100

# %% [markdown]
# Carregando o arquivo

# %%
df_previsao_de_renda = pd.read_csv('previsao_de_renda.csv')

# %%
df_previsao_de_renda.dtypes
# Out:
# Unnamed: 0                 int64
# data_ref                  object
# index                      int64
# sexo                      object
# posse_de_veiculo            bool
# posse_de_imovel             bool
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                      int64
# tempo_emprego            float64
# qt_pessoas_residencia    float64
# mau                         bool
# renda                    float64
# dtype: object

# %% [markdown]
# Plotando gráfico de pontos

# %%
ax = sns.pointplot(df_previsao_de_renda, x='posse_de_veiculo', y='renda')

# %%
ax = sns.pointplot(df_previsao_de_renda, x='posse_de_imovel', y='renda')

# %%
ax = sns.pointplot(df_previsao_de_renda, x='posse_de_imovel', y='renda', hue='posse_de_veiculo')

# %%
ax = sns.pointplot(df_previsao_de_renda, x='tipo_renda', y='renda', hue='posse_de_imovel')

# %% [markdown]
# Insight

# %% [markdown]
# A variável qualitativa posse_de_veículo se mostrou estatisticamente mais significativa para predizer a renda, visto que a sua média de renda do intervalo de confiança é superior à média da variável posse_de_imovel.
