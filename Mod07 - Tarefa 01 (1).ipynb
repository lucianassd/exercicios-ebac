# %% [markdown]
# # Módulo 07, Tarefa 01
#
# Vamos começar a mexer na nossa base de projeto? Já fizemos um exercício de montar a variável resposta, já pudemos perceber que essa atividade pode não ser trivial. Vamos agora trabalhar a base para que fique propícia ao *scikitlearn* para trabalharmos.
#
# Lembrando, a base se chama demo01.csv, e originalmente está publicada [aqui](https://www.kaggle.com/rikdifos/credit-card-approval-prediction).

# %% [markdown]
# #### 1) Carregue a base e avalie:
#
# - As variáveis
# - Tipos de dados de cada variável
# - Quantidade de missings
# - Distribuição da variável resposta (mau)

# %% [markdown]
# #### Biblioteca de importação

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### Leitura do arquivo

# %%
df_credit = pd.read_csv('demo01.csv')
df_credit.head(10)
# Out:
#   sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0    M                Y               Y           0               Working
# 1    F                N               Y           0  Commercial associate
# 2    F                N               Y           0  Commercial associate
# 3    M                Y               Y           0               Working
# 4    F                Y               N           0               Working
# 5    F                Y               N           0               Working
# 6    F                N               Y           0               Working
# 7    F                N               Y           0               Working
# 8    F                N               Y           1               Working
# 9    F                N               Y           1               Working
#
#                         educacao          estado_civil    tipo_residencia  \
# 0  Secondary / secondary special               Married  House / apartment
# ...

# %%
df_credit.shape
# Out:
# (16650, 16)

# %%
df_credit.info
# Out:
# <bound method DataFrame.info of       sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0        M                Y               Y           0               Working
# 1        F                N               Y           0  Commercial associate
# 2        F                N               Y           0  Commercial associate
# 3        M                Y               Y           0               Working
# 4        F                Y               N           0               Working
# ...    ...              ...             ...         ...                   ...
# 16645    F                N               Y           0               Working
# 16646    F                N               Y           0  Commercial associate
# 16647    M                Y               Y           0               Working
# 16648    M                Y               Y           0               Working
# 16649    F                N               Y           0             Pensioner
#
# ...

# %% [markdown]
# #### Verificação de dados faltantes

# %%
df_credit.isna().sum()
# Out:
# sexo                     0
# posse_de_veiculo         0
# posse_de_imovel          0
# qtd_filhos               0
# tipo_renda               0
# educacao                 0
# estado_civil             0
# tipo_residencia          0
# idade                    0
# tempo_emprego            0
# possui_celular           0
# possui_fone_comercial    0
# possui_fone              0
# possui_email             0
# qt_pessoas_residencia    0
# mau                      0
# dtype: int64

# %% [markdown]
# #### Verificação dos tipos dos dados

# %%
df_credit.dtypes
# Out:
# sexo                      object
# posse_de_veiculo          object
# posse_de_imovel           object
# qtd_filhos                 int64
# tipo_renda                object
# educacao                  object
# estado_civil              object
# tipo_residencia           object
# idade                    float64
# tempo_emprego            float64
# possui_celular             int64
# possui_fone_comercial      int64
# possui_fone                int64
# possui_email               int64
# qt_pessoas_residencia    float64
# mau                         bool
# dtype: object

# %% [markdown]
# #### Separando a variável explicativa

# %%
y = df_credit.mau
y
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16645     True
# 16646     True
# 16647     True
# 16648     True
# 16649     True
# Name: mau, Length: 16650, dtype: bool

# %%
x = df_credit.drop('mau', axis=1)
x
# Out:
#       sexo posse_de_veiculo posse_de_imovel  qtd_filhos            tipo_renda  \
# 0        M                Y               Y           0               Working
# 1        F                N               Y           0  Commercial associate
# 2        F                N               Y           0  Commercial associate
# 3        M                Y               Y           0               Working
# 4        F                Y               N           0               Working
# ...    ...              ...             ...         ...                   ...
# 16645    F                N               Y           0               Working
# 16646    F                N               Y           0  Commercial associate
# 16647    M                Y               Y           0               Working
# 16648    M                Y               Y           0               Working
# 16649    F                N               Y           0             Pensioner
#
# ...

# %% [markdown]
# #### 2) Vamos montar um metadados
#
# 1. Crie um dataframe com os nomes de cada variável e o tipo de dados de cada variável.
# 2. Adicione uma coluna nesse *dataframe* chamada "qtd_categorias" e coloque nela o número de categorias correspondente de cada variável.
#     Dica:
#         1. inicie uma lista vazia
#         2. faça um for ao longo dos nomes das variáveis,
#         3. conte o número de categorias dessa variável
#         4. acumule essa informação de 3. na lista que você criou em 1.
#         5. No final, essa lista pode ser atribuída à nossa variável.
# 3. Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}.

# %% [markdown]
# ####  Criação do novo DataFrame

# %%
meta_dados = pd.DataFrame(columns= ['variavel', 'tipo_dado'])
meta_dados
# Out:
# Empty DataFrame
# Columns: [variavel, tipo_dado]
# Index: []

# %% [markdown]
# #### Iterando sobre as variáveis

# %%
for col in df_credit.columns:
    meta_dados = pd.concat([meta_dados, pd.DataFrame({'variavel': [col], 'tipo_dado': [df_credit[col].dtype],
                                                     'qtd_categorias': [0]})])

# %% [markdown]
# #### Função para contagem do tipo de dado de cada variável

# %%
def cont_categorias(coluna):
    if coluna.dtype == 'object':
        return len(coluna.unique())
    return 0

# %% [markdown]
# #### Atribuindo contagem à nova coluna

# %%
meta_dados['qtd_categorias'] = df_credit.apply(cont_categorias)
meta_dados
# Out:
#                 variavel tipo_dado  qtd_categorias
# 0                   sexo    object             NaN
# 0       posse_de_veiculo    object             NaN
# 0        posse_de_imovel    object             NaN
# 0             qtd_filhos     int64             NaN
# 0             tipo_renda    object             NaN
# 0               educacao    object             NaN
# 0           estado_civil    object             NaN
# 0        tipo_residencia    object             NaN
# 0                  idade   float64             NaN
# 0          tempo_emprego   float64             NaN
# 0         possui_celular     int64             NaN
# 0  possui_fone_comercial     int64             NaN
# 0            possui_fone     int64             NaN
# 0           possui_email     int64             NaN
# 0  qt_pessoas_residencia   float64             NaN
# 0                    mau      bool             NaN

# %% [markdown]
# #### 3) Crie variáveis dummy para as variáveis necessárias (i.e. aquelas que são qualitativas e não estão armazenadas como {0, 1} ou {True, False}. Crie um *dataframe* apenas com as variáveis apropriadas para entrada no scikitlearn - elimine as variáveis tipo *str*, mantendo apenas suas versões *dummy*.

# %% [markdown]
# #### Identificando as variáveis do tipo str

# %%
list_object = []

for i in df_credit:
    if df_credit[i].dtype == 'object':
        uniq = df_credit[i].unique()
        list_object.append(i)
        list_object.append(uniq)

list_object
# Out:
# ['sexo',
#  array(['M', 'F'], dtype=object),
#  'posse_de_veiculo',
#  array(['Y', 'N'], dtype=object),
#  'posse_de_imovel',
#  array(['Y', 'N'], dtype=object),
#  'tipo_renda',
#  array(['Working', 'Commercial associate', 'State servant', 'Pensioner',
#         'Student'], dtype=object),
#  'educacao',
#  array(['Secondary / secondary special', 'Higher education',
#         'Incomplete higher', 'Lower secondary', 'Academic degree'],
#        dtype=object),
#  'estado_civil',
#  array(['Married', 'Single / not married', 'Civil marriage', 'Widow',
#         'Separated'], dtype=object),
#  'tipo_residencia',
#  array(['House / apartment', 'Rented apartment', 'Municipal apartment',
#         'With parents', 'Co-op apartment', 'Office apartment'],
#        dtype=object)]

# %% [markdown]
# #### Mapping

# %%
df_credit.sexo = df_credit.sexo.map({'F': 1, 'M':0})

# %%
df_credit.posse_de_imovel = df_credit.posse_de_imovel.map({'Y': 1, 'N':0})

# %%
df_credit.posse_de_veiculo = df_credit.posse_de_veiculo.map({'Y': 1, 'N':0})

# %% [markdown]
# #### Dummies

# %%
df_dummie = pd.get_dummies(df_credit, columns=['tipo_renda','educacao', 'estado_civil', 'tipo_residencia'], drop_first=True)
df_dummie.head(10)
# Out:
#    sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos      idade  \
# 0     0                 1                1           0  58.832877
# 1     1                 0                1           0  52.356164
# 2     1                 0                1           0  52.356164
# 3     0                 1                1           0  46.224658
# 4     1                 1                0           0  29.230137
# 5     1                 1                0           0  29.230137
# 6     1                 0                1           0  27.482192
# 7     1                 0                1           0  27.482192
# 8     1                 0                1           1  30.049315
# 9     1                 0                1           1  30.049315
#
#    tempo_emprego  possui_celular  possui_fone_comercial  possui_fone  \
# 0       3.106849               1                      0            0
# 1       8.358904               1                      0            1
# ...

# %% [markdown]
# #### Transformação do tipo de dado

# %%
df_dummie.idade = df_dummie.idade.astype(int)
df_dummie.tempo_emprego = df_dummie.tempo_emprego.astype(int)

df_dummie.head(3)
# Out:
#    sexo  posse_de_veiculo  posse_de_imovel  qtd_filhos  idade  tempo_emprego  \
# 0     0                 1                1           0     58              3
# 1     1                 0                1           0     52              8
# 2     1                 0                1           0     52              8
#
#    possui_celular  possui_fone_comercial  possui_fone  possui_email  ...  \
# 0               1                      0            0             0  ...
# 1               1                      0            1             1  ...
# 2               1                      0            1             1  ...
#
#    educacao_Secondary / secondary special  estado_civil_Married  \
# 0                                       1                     1
# 1                                       1                     0
# 2                                       1                     0
#
#    estado_civil_Separated  estado_civil_Single / not married  \
# ...

# %% [markdown]
# #### 4) Qual variável é mais poderosa?
#
# Considere as variáveis ```possui_email``` e ```posse_de_veiculo```. Faça uma tabela cruzada entre elas e responda qual delas te parece mais poderosa para prever a probabilidade de ```mau = 1```?

# %%
freq = pd.crosstab(df_credit['possui_email'], df_credit['posse_de_veiculo'])
freq
# Out:
# posse_de_veiculo     0     1
# possui_email
# 0                 9341  5829
# 1                  837   643

# %% [markdown]
# #### Resposta

# %% [markdown]
# A variável da posse_de_veiculo me parece mais importante para a análise por uma questão também de lógica financeira e de frequência maior em relação a quem possui email.

# %% [markdown]
# #### 5) Salve a base, pois ela será utilizada no final deste módulo.

# %%
df_dummie.to_csv('df_dummie.csv')
